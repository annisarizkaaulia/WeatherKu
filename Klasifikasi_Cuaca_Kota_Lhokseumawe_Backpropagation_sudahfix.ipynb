# %% [markdown]
# <a href="https://colab.research.google.com/github/annisarizkaaulia/WeatherKu/blob/main/Klasifikasi_Cuaca_Kota_Lhokseumawe_Backpropagation_sudahfix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Membaca file Excel
df = pd.read_excel('data_cuaca.xlsx')

# Mengambil kolom dan baris yang diinginkan
kolom_yang_diambil = ['NoStasiun', 'NamaStasiun', 'Tahun', 'Jam',
                      'Arah_angin', 'Kecepatan_angin', 'JarakPandang',
                      'Suhu', 'TitikEmbun','TekananQFF', 'Cuaca']
                      # Ganti dengan nama kolom yang diinginkan

# Membuat DataFrame baru dengan kolom dan baris yang diambil
# df_baru = df[kolom_yang_diambil].loc[baris_yang_diambil]
df_baru = df[kolom_yang_diambil]

# %%
df=df_baru.loc[df_baru['Tahun'] == 200]
df
# Out:
#        NoStasiun  NamaStasiun  Tahun  Jam  Arah_angin  Kecepatan_angin  \
# 31242      96009  Lhokseumawe    200    0         NaN              NaN
# 31243      96009  Lhokseumawe    200    1         NaN              NaN
# 31244      96009  Lhokseumawe    200    2         NaN              NaN
# 31245      96009  Lhokseumawe    200    3         NaN              NaN
# 31246      96009  Lhokseumawe    200    4         NaN              NaN
# ...          ...          ...    ...  ...         ...              ...
# 38004      96009  Lhokseumawe    200   19         NaN              NaN
# 38005      96009  Lhokseumawe    200   20         NaN              NaN
# 38006      96009  Lhokseumawe    200   21         NaN              NaN
# 38007      96009  Lhokseumawe    200   22         NaN              NaN
# 38008      96009  Lhokseumawe    200   23         NaN              NaN
#
#        JarakPandang  Suhu  TitikEmbun  TekananQFF  Cuaca
# 31242           NaN   NaN         NaN         NaN    NaN
# ...

# %%
# Menyimpan DataFrame baru ke file Excel
df=df_baru.loc[df_baru['Tahun'] != 200]
df.to_excel('datacuaca_new.xlsx', index=False)
df
# Out:
#        NoStasiun                       NamaStasiun  Tahun  Jam  Arah_angin  \
# 0          96009  Stasiun Meteorologi Malikussaleh   2018    0       140.0
# 1          96009  Stasiun Meteorologi Malikussaleh   2018    1       120.0
# 2          96009  Stasiun Meteorologi Malikussaleh   2018    2       120.0
# 3          96009  Stasiun Meteorologi Malikussaleh   2018    3       120.0
# 4          96009  Stasiun Meteorologi Malikussaleh   2018    4       110.0
# ...          ...                               ...    ...  ...         ...
# 38748      96009                       Lhokseumawe   2022   19       160.0
# 38749      96009                       Lhokseumawe   2022   20       180.0
# 38750      96009                       Lhokseumawe   2022   21       210.0
# 38751      96009                       Lhokseumawe   2022   22         0.0
# 38752      96009                       Lhokseumawe   2022   23         0.0
#
# ...

# %%
df.info() #melihat info data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38586 entries, 0 to 38752
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NoStasiun        38586 non-null  int64
#  1   NamaStasiun      38586 non-null  object
#  2   Tahun            38586 non-null  int64
#  3   Jam              38586 non-null  int64
#  4   Arah_angin       38584 non-null  float64
#  5   Kecepatan_angin  38584 non-null  float64
#  6   JarakPandang     38585 non-null  float64
#  7   Suhu             38585 non-null  float64
#  8   TitikEmbun       38584 non-null  float64
#  9   TekananQFF       38585 non-null  float64
#  10  Cuaca            9790 non-null   float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 3.5+ MB

# %%
df.isna().any() #melihat data yang null
# Out:
# NoStasiun          False
# NamaStasiun        False
# Tahun              False
# Jam                False
# Arah_angin          True
# Kecepatan_angin     True
# JarakPandang        True
# Suhu                True
# TitikEmbun          True
# TekananQFF          True
# Cuaca               True
# dtype: bool

# %%
df.isna().sum() #melihat data yang null
# Out:
# NoStasiun              0
# NamaStasiun            0
# Tahun                  0
# Jam                    0
# Arah_angin             2
# Kecepatan_angin        2
# JarakPandang           1
# Suhu                   1
# TitikEmbun             2
# TekananQFF             1
# Cuaca              28796
# dtype: int64

# %%
df=df.interpolate()
df
# Out:
#        NoStasiun                       NamaStasiun  Tahun  Jam  Arah_angin  \
# 0          96009  Stasiun Meteorologi Malikussaleh   2018    0       140.0
# 1          96009  Stasiun Meteorologi Malikussaleh   2018    1       120.0
# 2          96009  Stasiun Meteorologi Malikussaleh   2018    2       120.0
# 3          96009  Stasiun Meteorologi Malikussaleh   2018    3       120.0
# 4          96009  Stasiun Meteorologi Malikussaleh   2018    4       110.0
# ...          ...                               ...    ...  ...         ...
# 38748      96009                       Lhokseumawe   2022   19       160.0
# 38749      96009                       Lhokseumawe   2022   20       180.0
# 38750      96009                       Lhokseumawe   2022   21       210.0
# 38751      96009                       Lhokseumawe   2022   22         0.0
# 38752      96009                       Lhokseumawe   2022   23         0.0
#
# ...

# %%
#menghapuskan data tahun yg diinginkan
df=df[~df['Tahun'].isin([2022,2020,2019,2018])]
df
# Out:
#        NoStasiun                       NamaStasiun  Tahun  Jam  Arah_angin  \
# 26202      96009  Stasiun Meteorologi Malikussaleh   2021    0       150.0
# 26203      96009  Stasiun Meteorologi Malikussaleh   2021    1       150.0
# 26204      96009  Stasiun Meteorologi Malikussaleh   2021    2       150.0
# 26205      96009  Stasiun Meteorologi Malikussaleh   2021    3       170.0
# 26206      96009  Stasiun Meteorologi Malikussaleh   2021    4       120.0
# ...          ...                               ...    ...  ...         ...
# 29821      96009  Stasiun Meteorologi Malikussaleh   2021   19       250.0
# 29822      96009  Stasiun Meteorologi Malikussaleh   2021   20       220.0
# 29823      96009  Stasiun Meteorologi Malikussaleh   2021   21       230.0
# 29824      96009  Stasiun Meteorologi Malikussaleh   2021   22       220.0
# 29825      96009  Stasiun Meteorologi Malikussaleh   2021   23       220.0
#
# ...

# %%
df.isna().any()
# Out:
# NoStasiun          False
# NamaStasiun        False
# Tahun              False
# Jam                False
# Arah_angin         False
# Kecepatan_angin    False
# JarakPandang       False
# Suhu               False
# TitikEmbun         False
# TekananQFF         False
# Cuaca              False
# dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3624 entries, 26202 to 29825
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NoStasiun        3624 non-null   int64
#  1   NamaStasiun      3624 non-null   object
#  2   Tahun            3624 non-null   int64
#  3   Jam              3624 non-null   int64
#  4   Arah_angin       3624 non-null   float64
#  5   Kecepatan_angin  3624 non-null   float64
#  6   JarakPandang     3624 non-null   float64
#  7   Suhu             3624 non-null   float64
#  8   TitikEmbun       3624 non-null   float64
#  9   TekananQFF       3624 non-null   float64
#  10  Cuaca            3624 non-null   float64
# dtypes: float64(7), int64(3), object(1)
# memory usage: 339.8+ KB

# %%
df.to_excel('datacuaca_clean.xlsx', index=False) #export data yang sudah dibersikan
df
# Out:
#        NoStasiun                       NamaStasiun  Tahun  Jam  Arah_angin  \
# 26202      96009  Stasiun Meteorologi Malikussaleh   2021    0       150.0
# 26203      96009  Stasiun Meteorologi Malikussaleh   2021    1       150.0
# 26204      96009  Stasiun Meteorologi Malikussaleh   2021    2       150.0
# 26205      96009  Stasiun Meteorologi Malikussaleh   2021    3       170.0
# 26206      96009  Stasiun Meteorologi Malikussaleh   2021    4       120.0
# ...          ...                               ...    ...  ...         ...
# 29821      96009  Stasiun Meteorologi Malikussaleh   2021   19       250.0
# 29822      96009  Stasiun Meteorologi Malikussaleh   2021   20       220.0
# 29823      96009  Stasiun Meteorologi Malikussaleh   2021   21       230.0
# 29824      96009  Stasiun Meteorologi Malikussaleh   2021   22       220.0
# 29825      96009  Stasiun Meteorologi Malikussaleh   2021   23       220.0
#
# ...

# %%
df=df.drop(columns=['NoStasiun', 'NamaStasiun', 'Tahun', 'Jam']) #menghapus kolom nostasiun, namastasiun, tahun
df
# Out:
#        Arah_angin  Kecepatan_angin  JarakPandang  Suhu  TitikEmbun  \
# 26202       150.0             10.0           4.0  23.8        22.8
# 26203       150.0              8.0           6.0  24.0        22.7
# 26204       150.0              9.0           4.0  24.0        22.4
# 26205       170.0              4.0           6.0  24.6        22.1
# 26206       120.0              5.0           7.0  27.8        23.4
# ...           ...              ...           ...   ...         ...
# 29821       250.0              2.0           6.0  24.3        23.6
# 29822       220.0              3.0           6.0  24.0        23.3
# 29823       230.0              4.0           6.0  23.9        23.1
# 29824       220.0              4.0           7.0  23.9        23.1
# 29825       220.0              4.0           8.0  23.9        22.9
#
#        TekananQFF      Cuaca
# 26202      1010.1  61.000000
# 26203      1010.8  21.000000
# 26204      1011.7  60.000000
# 26205      1011.9  21.000000
# ...

# %% [markdown]
# **Mengubah data kategori cuaca BMKG menjadi kategori yang diinginkan (cerah,berawan, hujan)**
# ---

# %%
# df = pd.read_excel('datacuacaprediksi.xlsx')

# Menerapkan kondisi if, elif, else pada kolom 'KolomA'
def apply_condition(row):
    if row['Cuaca'] <= 3:
        return 'Cerah'
    elif row['Cuaca'] <= 19:
        return 'Berawan'
    else:
        return 'Hujan'

df['Cuaca'] = df.apply(apply_condition, axis=1)

# Menyimpan hasil perubahan ke file Excel baru
df.to_excel('dataset_weather.xlsx', index=False)

# %%
df = pd.read_excel('dataset_weather.xlsx')
df
# Out:
#       Arah_angin  Kecepatan_angin  JarakPandang  Suhu  TitikEmbun  TekananQFF  \
# 0            150               10           4.0  23.8        22.8      1010.1
# 1            150                8           6.0  24.0        22.7      1010.8
# 2            150                9           4.0  24.0        22.4      1011.7
# 3            170                4           6.0  24.6        22.1      1011.9
# 4            120                5           7.0  27.8        23.4      1011.7
# ...          ...              ...           ...   ...         ...         ...
# 3619         250                2           6.0  24.3        23.6      1006.8
# 3620         220                3           6.0  24.0        23.3      1007.1
# 3621         230                4           6.0  23.9        23.1      1007.1
# 3622         220                4           7.0  23.9        23.1      1007.4
# 3623         220                4           8.0  23.9        22.9      1007.8
#
#         Cuaca
# 0       Hujan
# ...

# %%
df.shape
# Out:
# (3624, 7)

# %%
df.nunique()
# Out:
# Arah_angin          38
# Kecepatan_angin     19
# JarakPandang        13
# Suhu               123
# TitikEmbun          72
# TekananQFF         106
# Cuaca                3
# dtype: int64

# %%
df.columns
# Out:
# Index(['Arah_angin', 'Kecepatan_angin', 'JarakPandang', 'Suhu', 'TitikEmbun',
#        'TekananQFF', 'Cuaca'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Arah_angin         0
# Kecepatan_angin    0
# JarakPandang       0
# Suhu               0
# TitikEmbun         0
# TekananQFF         0
# Cuaca              0
# dtype: int64

# %%
df.describe()
# Out:
#         Arah_angin  Kecepatan_angin  JarakPandang         Suhu   TitikEmbun  \
# count  3624.000000      3624.000000   3624.000000  3624.000000  3624.000000
# mean    153.270971         4.230684     34.060844    26.980911    23.625993
# std      97.333681         2.735418   1661.015022     2.617000     1.073582
# min       0.000000         0.000000      0.500000    21.000000    18.700000
# 25%      70.000000         2.000000      6.000000    24.700000    23.000000
# 50%     150.000000         3.000000      6.000000    26.600000    23.700000
# 75%     220.000000         6.000000      7.000000    29.300000    24.300000
# max     360.000000        40.000000  99999.000000    34.600000    26.700000
#
#         TekananQFF
# count  3624.000000
# mean   1009.617660
# std       1.865682
# min    1003.600000
# 25%    1008.400000
# 50%    1009.600000
# 75%    1011.000000
# max    1014.800000

# %%
df.groupby(['Cuaca']).size()
# Out:
# Cuaca
# Berawan    2523
# Cerah       245
# Hujan       856
# dtype: int64

# %%
numerical=['Arah_angin','Kecepatan_angin',	'JarakPandang',	'Suhu',	'TitikEmbun',	'TekananQFF']
target=['Cuaca']

# %% [markdown]
# # **Feature Encoding**

# %%
ports={"Cerah":0,"Berawan":1,"Hujan":2}
df['Cuaca']=df['Cuaca'].map(ports)
df
# from sklearn.preprocessing import LabelEncoder
# le=LabelEncoder()
# Y = le.fit_transform(df['Cuaca'])
# Out:
#       Arah_angin  Kecepatan_angin  JarakPandang  Suhu  TitikEmbun  TekananQFF  \
# 0            150               10           4.0  23.8        22.8      1010.1
# 1            150                8           6.0  24.0        22.7      1010.8
# 2            150                9           4.0  24.0        22.4      1011.7
# 3            170                4           6.0  24.6        22.1      1011.9
# 4            120                5           7.0  27.8        23.4      1011.7
# ...          ...              ...           ...   ...         ...         ...
# 3619         250                2           6.0  24.3        23.6      1006.8
# 3620         220                3           6.0  24.0        23.3      1007.1
# 3621         230                4           6.0  23.9        23.1      1007.1
# 3622         220                4           7.0  23.9        23.1      1007.4
# 3623         220                4           8.0  23.9        22.9      1007.8
#
#       Cuaca
# 0         2
# ...

# %% [markdown]
# # **Feature Scaling**

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
df.describe()
# Out:
#         Arah_angin  Kecepatan_angin  JarakPandang         Suhu   TitikEmbun  \
# count  3624.000000      3624.000000   3624.000000  3624.000000  3624.000000
# mean    153.270971         4.230684     34.060844    26.980911    23.625993
# std      97.333681         2.735418   1661.015022     2.617000     1.073582
# min       0.000000         0.000000      0.500000    21.000000    18.700000
# 25%      70.000000         2.000000      6.000000    24.700000    23.000000
# 50%     150.000000         3.000000      6.000000    26.600000    23.700000
# 75%     220.000000         6.000000      7.000000    29.300000    24.300000
# max     360.000000        40.000000  99999.000000    34.600000    26.700000
#
#         TekananQFF        Cuaca
# count  3624.000000  3624.000000
# mean   1009.617660     1.168598
# std       1.865682     0.524841
# min    1003.600000     0.000000
# 25%    1008.400000     1.000000
# 50%    1009.600000     1.000000
# 75%    1011.000000     1.000000
# ...

# %%
numerical
# Out:
# ['Arah_angin',
#  'Kecepatan_angin',
#  'JarakPandang',
#  'Suhu',
#  'TitikEmbun',
#  'TekananQFF']

# %%
scaler=StandardScaler()
df[numerical]=scaler.fit_transform(df[numerical].values)
df
# Out:
#       Arah_angin  Kecepatan_angin  JarakPandang      Suhu  TitikEmbun  \
# 0      -0.033610         2.109407     -0.018100 -1.215647   -0.769487
# 1      -0.033610         1.378157     -0.016896 -1.139213   -0.862646
# 2      -0.033610         1.743782     -0.018100 -1.139213   -1.142123
# 3       0.171897        -0.084344     -0.016896 -0.909912   -1.421600
# 4      -0.341871         0.281281     -0.016294  0.313031   -0.210533
# ...          ...              ...           ...       ...         ...
# 3619    0.993925        -0.815594     -0.016896 -1.024563   -0.024215
# 3620    0.685664        -0.449969     -0.016896 -1.139213   -0.303692
# 3621    0.788418        -0.084344     -0.016896 -1.177430   -0.490010
# 3622    0.685664        -0.084344     -0.016294 -1.177430   -0.490010
# 3623    0.685664        -0.084344     -0.015692 -1.177430   -0.676328
#
#       TekananQFF  Cuaca
# 0       0.258568      2
# 1       0.633818      2
# 2       1.116282      2
# 3       1.223496      2
# ...

# %% [markdown]
# # **split data**

# %%
X=df.drop(['Cuaca'],axis=1)
Y=df['Cuaca']
X.columns
# Out:
# Index(['Arah_angin', 'Kecepatan_angin', 'JarakPandang', 'Suhu', 'TitikEmbun',
#        'TekananQFF'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 100)

# %%
X_train.shape
# Out:
# (2899, 6)

# %%
X_test.shape
# Out:
# (725, 6)

# %%
Y_train.shape
# Out:
# (2899,)

# %%
Y_test.shape
# Out:
# (725,)

# %%
# class myCallback(tf.keras.callbacks.Callback):
#   # Define the correct function signature for on_epoch_end
#   def on_epoch_end(self, epoch, logs={}):
#     if logs.get('accuracy') is not None and logs.get('accuracy') > 0.80:
#       print("\nReached 80% accuracy so cancelling training!")
#       # Stop training once the above condition is met
#       self.model.stop_training = True
# callbacks = myCallback()

# %% [markdown]
# # **Arsitektur *Backpropagation* dan optimasi ADAM**

# %%
import tensorflow as tf
# Create the model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer=tf.keras.optimizers.Adam(0.01),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Now you can call the fit() method
historytrain =model.fit(X_train, Y_train, epochs=1000, batch_size=128)
model.evaluate(X_train, Y_train, batch_size=128)
# Out:
# Epoch 1/1000
# 23/23 [==============================] - 1s 1ms/step - loss: 0.8412 - accuracy: 0.6568
# Epoch 2/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7575 - accuracy: 0.6958
# Epoch 3/1000
# 23/23 [==============================] - 0s 2ms/step - loss: 0.7514 - accuracy: 0.6958
# Epoch 4/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7467 - accuracy: 0.6985
# Epoch 5/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7397 - accuracy: 0.7027
# Epoch 6/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7340 - accuracy: 0.7085
# Epoch 7/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7276 - accuracy: 0.7085
# Epoch 8/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7267 - accuracy: 0.7078
# Epoch 9/1000
# 23/23 [==============================] - 0s 1ms/step - loss: 0.7273 - accuracy: 0.7082
# Epoch 10/1000
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 6)                 42
#
#  dense_7 (Dense)             (None, 64)                448
#
#  dense_8 (Dense)             (None, 3)                 195
#
# ...
# Total params: 685
# Trainable params: 685
# Non-trainable params: 0
# _________________________________________________________________

# %%
historytest = model.fit(X_test, Y_test, epochs=1000, batch_size=128)
model.evaluate(X_test, Y_test, batch_size=128)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.8529 - accuracy: 0.7034
# Epoch 2/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7544 - accuracy: 0.7172
# Epoch 3/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7260 - accuracy: 0.7172
# Epoch 4/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6967 - accuracy: 0.7159
# Epoch 5/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6766 - accuracy: 0.7228
# Epoch 6/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6581 - accuracy: 0.7379
# Epoch 7/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6361 - accuracy: 0.7338
# Epoch 8/1000
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6213 - accuracy: 0.7407
# Epoch 9/1000
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6062 - accuracy: 0.7531
# Epoch 10/1000
# ...

# %%
import matplotlib.pyplot as plt

acctrain = historytrain.history['accuracy']
acctest = historytest.history['accuracy']
losstrain = historytrain.history['loss']
losstest = historytest.history['loss']

epochsacctrain = range(len(acctrain))
epochslosstrain = range(len(losstrain))
epochsacctest = range(len(acctest))
epochslosstest = range(len(losstest))

plt.plot(epochsacctrain, acctrain, 'b', label='training accuracy')
plt.title('Training accuracy')
plt.plot(epochsacctest, acctest, 'r', label='Testing accuracy')
plt.title('Testing accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

plt.plot(epochslosstrain, losstrain, 'b', label='Training loss')
plt.title('Training loss')
plt.plot(epochslosstest, losstest, 'r', label='Testing loss')
plt.title('Testing loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# def download_history():
#   import pickle
#   from google.colab import files

#   with open('historyweather.pkl', 'wb') as f:
#     pickle.dump(model, f)

#   files.download('historyweather.pkl')

# download_history()

# %%
# import pickle
# with open("historyweather.pkl", "rb") as file:
#     model = pickle.load(file)

# %%
model.save("modelweather.h5")

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 6)                 42
#
#  dense_7 (Dense)             (None, 64)                448
#
#  dense_8 (Dense)             (None, 3)                 195
#
# ...
# Total params: 685
# Trainable params: 685
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
import pandas as pd
df = pd.read_excel('datacuaca_new.xlsx')
X =df.drop(['Cuaca'],axis=1)
X
# Out:
#        NoStasiun                       NamaStasiun  Tahun  Jam  Arah_angin  \
# 0          96009  Stasiun Meteorologi Malikussaleh   2018    0       140.0
# 1          96009  Stasiun Meteorologi Malikussaleh   2018    1       120.0
# 2          96009  Stasiun Meteorologi Malikussaleh   2018    2       120.0
# 3          96009  Stasiun Meteorologi Malikussaleh   2018    3       120.0
# 4          96009  Stasiun Meteorologi Malikussaleh   2018    4       110.0
# ...          ...                               ...    ...  ...         ...
# 38581      96009                       Lhokseumawe   2022   19       160.0
# 38582      96009                       Lhokseumawe   2022   20       180.0
# 38583      96009                       Lhokseumawe   2022   21       210.0
# 38584      96009                       Lhokseumawe   2022   22         0.0
# 38585      96009                       Lhokseumawe   2022   23         0.0
#
#        Kecepatan_angin  JarakPandang  Suhu  TitikEmbun  TekananQFF
# ...

# %%
X = X[~X['Tahun'].isin([2022, 2021, 2020, 2018])]
X
# Out:
#        NoStasiun                       NamaStasiun  Tahun  Jam  Arah_angin  \
# 8760       96009  Stasiun Meteorologi Malikussaleh   2019    0       200.0
# 8761       96009  Stasiun Meteorologi Malikussaleh   2019    1       220.0
# 8762       96009  Stasiun Meteorologi Malikussaleh   2019    2       200.0
# 8763       96009  Stasiun Meteorologi Malikussaleh   2019    3         0.0
# 8764       96009  Stasiun Meteorologi Malikussaleh   2019    4        90.0
# ...          ...                               ...    ...  ...         ...
# 17515      96009  Stasiun Meteorologi Malikussaleh   2019   19       160.0
# 17516      96009  Stasiun Meteorologi Malikussaleh   2019   20       120.0
# 17517      96009  Stasiun Meteorologi Malikussaleh   2019   21       110.0
# 17518      96009  Stasiun Meteorologi Malikussaleh   2019   22       120.0
# 17519      96009  Stasiun Meteorologi Malikussaleh   2019   23       120.0
#
#        Kecepatan_angin  JarakPandang  Suhu  TitikEmbun  TekananQFF
# ...

# %%
X=X.drop(columns=['NoStasiun', 'NamaStasiun', 'Tahun', 'Jam']) #menghapus kolom nostasiun, namastasiun, tahun
X
# Out:
#        Arah_angin  Kecepatan_angin  JarakPandang  Suhu  TitikEmbun  TekananQFF
# 8760        200.0              3.0           6.0  22.4        21.1      1014.2
# 8761        220.0              4.0           6.0  23.2        21.0      1014.8
# 8762        200.0              2.0           6.0  26.0        22.1      1015.3
# 8763          0.0              0.0           6.0  28.8        22.6      1015.2
# 8764         90.0              2.0           7.0  30.2        22.3      1014.9
# ...           ...              ...           ...   ...         ...         ...
# 17515       160.0              4.0           7.0  23.6        22.3      1012.8
# 17516       120.0              5.0           7.0  24.0        22.1      1012.3
# 17517       110.0              5.0           7.0  24.3        22.0      1011.9
# 17518       120.0              5.0           7.0  24.3        22.0      1012.0
# 17519       120.0              5.0           7.0  24.4        21.9      1012.3
#
# [8760 rows x 6 columns]

# %%
x = np.array([X])
x.shape
# Out:
# (1, 8760, 6)

# %%
data_tes=x[0][12]
data_tes=np.expand_dims(data_tes, axis=0)
data_tes
# Out:
# array([[1.6000e+02, 1.0000e+00, 7.0000e+00, 2.7600e+01, 2.4200e+01,
#         1.0138e+03]])

# %%
result = model.predict(data_tes)
result
# Out:
# 1/1 [==============================] - 0s 54ms/step
# array([[0., 0., 1.]], dtype=float32)

# %%
class_names = ["Cerah", "Berawan", "Hujan"]

# Perform the prediction
prediction = model.predict(data_tes)

# Get the index of the predicted class label
predicted_index = np.argmax(prediction)

# Get the corresponding class label from the class_names list
predicted_label = class_names[predicted_index]

print(predicted_label)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# Hujan

# %%
# !pip freeze > requirementsweather.txt

# %% [markdown]
# **Accuracy testing**

# %%
X_test #ngecek akurasi
# Out:
#       Arah_angin  Kecepatan_angin  JarakPandang      Suhu  TitikEmbun  \
# 323    -0.136364         0.646906     -0.016896 -0.069139    0.162103
# 2752   -0.033610        -0.449969     -0.016896 -0.833478    0.162103
# 696    -1.574913        -1.546845     -0.016896 -1.903553   -2.166872
# 1147    0.582911        -0.449969     -0.016896 -1.521383   -2.073713
# 2645    2.021460         1.378157     -0.015692  1.459540    0.348421
# ...          ...              ...           ...       ...         ...
# 3362   -0.033610         0.281281     -0.016896  0.083729    0.441580
# 562    -1.266653         1.012532     -0.016896  0.695201   -0.396851
# 1264   -0.239117        -0.815594     -0.016896 -0.451308    1.280010
# 1078    0.685664        -0.449969     -0.016896 -0.986346   -0.490010
# 299    -0.650132         1.743782     -0.016896 -0.030922   -1.235282
#
#       TekananQFF
# 323    -0.545538
# 2752    0.741032
# 696     0.687425
# 1147    0.741032
# 2645    1.009068
# ...

# %%
# df = pd.read_excel('dataset_weather.xlsx')
# Y = df['Cuaca']
# X = df.drop(['Cuaca'],axis=1)
# X = X.to_numpy()
# X
Y_test
# Out:
# ['cerah',
#  'cerah',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'hujan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'cerah',
#  'cerah',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'cerah',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'cerah',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'cerah',
#  'hujan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'berawan',
#  'hujan',
#  'hujan',
#  'berawan',
#  'hujan',
#  'hujan',
#  'hujan',
#  'hujan',
# ...

# %%
# # Ambil kolom Cuaca dari DataFrame sebagai Series
# cuaca_series = df['Cuaca']

# # Ubah Series menjadi array dengan metode to_numpy()
# Y = cuaca_series.to_numpy()

# # Atau, Anda juga bisa menggunakan metode values()
# # cuaca_array = cuaca_series.values

# # Cetak array hasil konversi
# print(Y)

# %%
Y_pre = model.predict(X_test)
Y_prediction = []

for i in range(len(Y_pre)):
  prediction = np.argmax(Y_pre[i])
  Y_prediction.append(prediction)

# Menggunakan mapping antara nilai encoding dan label kategorikal
encoding_mapping = {0: 'cerah', 1: 'berawan', 2: 'hujan'}

# Mengonversi nilai encoding menjadi label kategorikal
Y_prediction = [encoding_mapping[label] for label in Y_prediction]

# Menampilkan hasil prediksi kategorikal
print(Y_prediction)
# Out:
# 23/23 [==============================] - 0s 2ms/step
# ...

# %%
# Menghitung jumlah prediksi yang benar
correct_predictions = 0
for true_label, pred_label in zip(Y_test, Y_prediction):
    if true_label == pred_label:
        correct_predictions += 1

# Menghitung jumlah total data
total_data = len(Y_test)

# Menghitung akurasi
accuracy = correct_predictions / total_data

print("Akurasi:", accuracy)
# Out:
# Akurasi: 0.9296551724137931
